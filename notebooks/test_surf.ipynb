# %%
import requests
import json
from pprint import pprint
import os
from dotenv import load_dotenv
from pprint import pprint

# Load environment variables from repo root
load_dotenv("../.env")

api_key = os.getenv("SURF_API_KEY")
willma_base_url = os.getenv("SURF_API_BASE", "https://willma.surf.nl/api/v0")

if not api_key:
    raise ValueError("SURF_API_KEY is not set in .env")

headers = {"X-API-KEY": api_key, "Content-Type": "application/json"}

models = requests.get(f"{willma_base_url}/sequences", headers=headers, timeout=30).json()
text_models = [m["name"] for m in models if m.get("sequence_type") == "text"]

print("Available text models:", text_models)
model_name = "default-text-large" if "default-text-large" in text_models else (text_models[0] if text_models else None)
if not model_name:
    raise RuntimeError("No text models returned by /sequences")
pprint(text_models)
# Out:
# Available text models: ['Qwen 2.5 Coder 32B Instruct AWQ', 'default-text-large', 'mistralai/Mistral-Small-3.2-24B-Instruct-2506', 'openai/gpt-oss-120b', 'Sehyo/Qwen3.5-122B-A10B-NVFP4']
# ['Qwen 2.5 Coder 32B Instruct AWQ',
#  'default-text-large',
#  'mistralai/Mistral-Small-3.2-24B-Instruct-2506',
#  'openai/gpt-oss-120b',
#  'Sehyo/Qwen3.5-122B-A10B-NVFP4']

# %%
response = requests.post(
    f"{willma_base_url}/chat/completions",
    data=json.dumps({
        "model": model_name,
        "messages": [{"role": "user", "content": "Hoi!"}],
    }),
    headers=headers,
    timeout=60,
).json()

# %%
models
# Out:
# [{'description': 'Release Date: December 2023',
#   'sequence_type': 'stt',
#   'id': 7,
#   'user_id': None,
#   'web_visible': True,
#   'name': 'Whisper speech-to-text Dutch',
#   'sequence': [{'model_id': 7, 'type': 'stt'}],
#   'shared_to_co': None},
#  {'description': 'Qwen 2.5 Coder 32B Instruct AWQ',
#   'sequence_type': 'text',
#   'id': 27,
#   'user_id': None,
#   'web_visible': None,
#   'name': 'Qwen 2.5 Coder 32B Instruct AWQ',
#   'sequence': [{'model_id': 27, 'type': 'text'}],
#   'shared_to_co': None},
#  {'description': 'The current default text model',
#   'sequence_type': 'text',
#   'id': 29,
#   'user_id': None,
#   'web_visible': None,
#   'name': 'default-text-large',
#   'sequence': [{'model_id': 23, 'type': 'text'}],
#   'shared_to_co': None},
#  {'description': '',
#   'sequence_type': 'text',
#   'id': 44,
#   'user_id': None,
#   'web_visible': None,
#   'name': 'mistralai/Mistral-Small-3.2-24B-Instruct-2506',
#   'sequence': [{'model_id': 40, 'type': 'text'}],
#   'shared_to_co': None},
#  {'description': 'Welcome to the gpt-oss series, OpenAI’s open-weight models designed for powerful reasoning, agentic tasks, and versatile developer use cases.',
#   'sequence_type': 'text',
#   'id': 45,
#   'user_id': None,
#   'web_visible': None,
#   'name': 'openai/gpt-oss-120b',
#   'sequence': [{'model_id': 41, 'type': 'text'}],
#   'shared_to_co': None},
#  {'description': '',
#   'sequence_type': 'embedder',
#   'id': 47,
#   'user_id': None,
#   'web_visible': None,
#   'name': 'Qwen/Qwen3-Embedding-8B',
#   'sequence': [{'model_id': 43, 'type': 'embedder'}],
#   'shared_to_co': None},
#  {'description': '',
#   'sequence_type': 'text',
#   'id': 50,
#   'user_id': None,
#   'web_visible': None,
#   'name': 'Sehyo/Qwen3.5-122B-A10B-NVFP4',
#   'sequence': [{'model_id': 46, 'type': 'text'}],
#   'shared_to_co': None}]

# %% [markdown]
# The selected model is discovered from `/sequences` and stored in `model_name`.
#
# If you want a fixed model, set `model_name` manually after running the first cell.
